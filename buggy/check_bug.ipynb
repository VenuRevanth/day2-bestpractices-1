# %%
run main.py
# Out:
# Add the values of the dice
# It's really that easy
# What are you doing with your life.
# > c:\users\revan\day2-bestpractices-1\buggy\main.py(9)main()
#       8     import ipdb; ipdb.set_trace()
# ----> 9     GameRunner.run()
#      10
# ipdb>  s
# --Call--
# > c:\users\revan\day2-bestpractices-1\buggy\dicegame\runner.py(21)run()
#      20
# ---> 21     @classmethod
#      22     def run(cls):
# ipdb>  s
# > c:\users\revan\day2-bestpractices-1\buggy\dicegame\runner.py(25)run()
#      24         # Great variable name, 10/10.
# ---> 25         c = 0
#      26         while True:
# ipdb>  s
# > c:\users\revan\day2-bestpractices-1\buggy\dicegame\runner.py(26)run()
#      25         c = 0
# ---> 26         while True:
#      27             runner = cls()
# ipdb>  s
# > c:\users\revan\day2-bestpractices-1\buggy\dicegame\runner.py(27)run()
#      26         while True:
# ---> 27             runner = cls()
#      28
# ipdb>  s
# --Call--
# ...
